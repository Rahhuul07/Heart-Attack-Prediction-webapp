# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Personal Projects\ML\Project_1\Heart_Attack.csv")

# %%
df.head()
# Out:
#    age  gender  impluse  pressurehight  pressurelow  glucose    kcm  troponin  \
# 0   64       1       66            160           83    160.0   1.80     0.012
# 1   21       1       94             98           46    296.0   6.75     1.060
# 2   55       1       64            160           77    270.0   1.99     0.003
# 3   64       1       70            120           55    270.0  13.87     0.122
# 4   55       1       64            112           65    300.0   1.08     0.003
#
#       class
# 0  negative
# 1  positive
# 2  negative
# 3  positive
# 4  negative

# %%
df.shape
# Out:
# (1319, 9)

# %%
df.describe()
# Out:
#                age       gender      impluse  pressurehight  pressurelow  \
# count  1319.000000  1319.000000  1319.000000    1319.000000  1319.000000
# mean     56.191812     0.659591    78.336619     127.170584    72.269143
# std      13.647315     0.474027    51.630270      26.122720    14.033924
# min      14.000000     0.000000    20.000000      42.000000    38.000000
# 25%      47.000000     0.000000    64.000000     110.000000    62.000000
# 50%      58.000000     1.000000    74.000000     124.000000    72.000000
# 75%      65.000000     1.000000    85.000000     143.000000    81.000000
# max     103.000000     1.000000  1111.000000     223.000000   154.000000
#
#            glucose          kcm     troponin
# count  1319.000000  1319.000000  1319.000000
# mean    146.634344    15.274306     0.360942
# std      74.923045    46.327083     1.154568
# min      35.000000     0.321000     0.001000
# 25%      98.000000     1.655000     0.006000
# ...

# %%
#Convert

# %%
df.head()
# Out:
#    age  gender  impluse  pressurehight  pressurelow  glucose    kcm  troponin  \
# 0   64       1       66            160           83    160.0   1.80     0.012
# 1   21       1       94             98           46    296.0   6.75     1.060
# 2   55       1       64            160           77    270.0   1.99     0.003
# 3   64       1       70            120           55    270.0  13.87     0.122
# 4   55       1       64            112           65    300.0   1.08     0.003
#
#       class
# 0  negative
# 1  positive
# 2  negative
# 3  positive
# 4  negative

# %%
df.describe()
# Out:
#                age       gender      impluse  pressurehight  pressurelow  \
# count  1319.000000  1319.000000  1319.000000    1319.000000  1319.000000
# mean     56.191812     0.659591    78.336619     127.170584    72.269143
# std      13.647315     0.474027    51.630270      26.122720    14.033924
# min      14.000000     0.000000    20.000000      42.000000    38.000000
# 25%      47.000000     0.000000    64.000000     110.000000    62.000000
# 50%      58.000000     1.000000    74.000000     124.000000    72.000000
# 75%      65.000000     1.000000    85.000000     143.000000    81.000000
# max     103.000000     1.000000  1111.000000     223.000000   154.000000
#
#            glucose          kcm     troponin
# count  1319.000000  1319.000000  1319.000000
# mean    146.634344    15.274306     0.360942
# std      74.923045    46.327083     1.154568
# min      35.000000     0.321000     0.001000
# 25%      98.000000     1.655000     0.006000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            1319 non-null   int64
#  1   gender         1319 non-null   int64
#  2   impluse        1319 non-null   int64
#  3   pressurehight  1319 non-null   int64
#  4   pressurelow    1319 non-null   int64
#  5   glucose        1319 non-null   float64
#  6   kcm            1319 non-null   float64
#  7   troponin       1319 non-null   float64
#  8   class          1319 non-null   object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 92.9+ KB

# %%
df["class"].value_counts()
# Out:
# class
# positive    810
# negative    509
# Name: count, dtype: int64

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of       age  gender  impluse  pressurehight  pressurelow  glucose    kcm  \
# 0      64       1       66            160           83    160.0   1.80
# 1      21       1       94             98           46    296.0   6.75
# 2      55       1       64            160           77    270.0   1.99
# 3      64       1       70            120           55    270.0  13.87
# 4      55       1       64            112           65    300.0   1.08
# ...   ...     ...      ...            ...          ...      ...    ...
# 1314   44       1       94            122           67    204.0   1.63
# 1315   66       1       84            125           55    149.0   1.33
# 1316   45       1       85            168          104     96.0   1.24
# 1317   54       1       58            117           68    443.0   5.80
# 1318   51       1       94            157           79    134.0  50.89
#
#       troponin     class
# 0        0.012  negative
# 1        1.060  positive
# ...

# %%
plt.figure(figsize=(9, 7))  # Adjust the figure size as needed
sns.countplot(x='class',color=('seagreen'),data=df)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Distribution of Class')
plt.show()

# %%
plt.figure(figsize=(9, 7))
labels =['positive','negative']
sizes = df['class'].value_counts()
colors = ['seagreen', 'chocolate']
explode = (0, 0.05)

# Create a pie chart

plt.pie(sizes, labels=labels, colors=colors, explode=explode, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Class Distribution')


# Display the pie chart
plt.show()

# %%
X = df[['age','gender','impluse','pressurehight','pressurelow','glucose','kcm','troponin']]
y = df['class']

# %%
 #Create the RandomUnderSampler object with appropriate sampling strategy
import pandas as pd
from imblearn.under_sampling import RandomUnderSampler
import matplotlib.pyplot as plt
rus = RandomUnderSampler(sampling_strategy="auto")

# Fit and resample the data
X_res, y_res = rus.fit_resample(X, y)

# Plot the value counts of the resampled target variable
plt.figure(figsize=(9, 7))
ax = y_res.value_counts().plot.pie(colors=['seagreen', 'chocolate'],explode =(0,0.05),autopct='%1.1f%%')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
X_res_train,X_res_test,y_res_train,y_res_test = train_test_split(X_res,y_res,test_size = 0.3, random_state=1)

# %%
log = LogisticRegression()
log.fit(X_res_train,y_res_train)
# Out:
# D:\Personal Projects\ML\Project_2\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_res_pred = log.predict(X_res_test)

# %%
confusion_matrix(y_res_test,y_res_pred)
# Out:
# array([[138,  15],
#        [ 46, 107]], dtype=int64)

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
print(accuracy_score(y_res_test,y_res_pred)*100,"%")
# Out:
# 80.06535947712419 %

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier

# %%
X_res_train,X_res_test,y_res_train,y_res_test = train_test_split(X_res,y_res,test_size = 0.3,random_state=1)

# %%
dec = DecisionTreeClassifier()
dec.fit(X_res_train,y_res_train)
# Out:
# DecisionTreeClassifier()

# %%
y_res_predict = dec.predict(X_res_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_res_test,y_res_predict)*100)
# Out:
# 98.0392156862745

# %%
#KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
Knn = KNeighborsClassifier()
Knn.fit(X_res_train,y_res_train)
# Out:
# KNeighborsClassifier()

# %%
y_res_pred = Knn.predict(X_res_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_res_test,y_res_predict)*100)
# Out:
# 98.0392156862745

# %%
#RandomForest
from sklearn.ensemble import RandomForestClassifier

# %%
rand = RandomForestClassifier()
rand.fit(X_res_train,y_res_train)
# Out:
# RandomForestClassifier()

# %%
y_res_pred = rand.predict(X_res_test)
y_res_pred
# Out:
# array(['negative', 'negative', 'positive', 'negative', 'negative',
#        'negative', 'positive', 'negative', 'negative', 'negative',
#        'positive', 'negative', 'positive', 'positive', 'negative',
#        'positive', 'positive', 'negative', 'negative', 'positive',
#        'negative', 'negative', 'negative', 'negative', 'positive',
#        'negative', 'positive', 'positive', 'negative', 'negative',
#        'negative', 'negative', 'positive', 'negative', 'positive',
#        'negative', 'negative', 'negative', 'negative', 'positive',
#        'negative', 'negative', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'negative', 'positive', 'positive',
#        'positive', 'negative', 'negative', 'negative', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'positive', 'negative',
#        'negative', 'negative', 'negative', 'negative', 'negative',
# ...

# %%
print(accuracy_score(y_res_test, y_res_pred)*100)
# Out:
# 98.36601307189542

# %%
#Support Vector Machine
from sklearn.svm import SVC

# %%
X_res_train, X_res_test,y_res_train, y_res_test = train_test_split(X_res,y_res,test_size=0.3,random_state=1)

# %%
svc = SVC()
svc.fit(X_res_train,y_res_train)
# Out:
# SVC()

# %%
y_res_pred = svc.predict(X_res_test)

# %%
print(accuracy_score(y_res_test, y_res_pred))
# Out:
# 0.6405228758169934

# %%
#Prep for streamlit
X_res_test
# Out:
#       age  gender  impluse  pressurehight  pressurelow  glucose    kcm  \
# 688    45       1       58            156           76     97.0   2.86
# 332    75       0       80            108           79    168.0   2.60
# 1178   66       1       73            125           78    112.0   2.87
# 443    35       1       78            149           77     92.0   1.51
# 1244   37       1       88            119           66    118.0   5.78
# ...   ...     ...      ...            ...          ...      ...    ...
# 152    58       1      103             78           92    109.0   3.84
# 125    47       1      125            121           60     89.0   2.27
# 404    72       1       79            159          110    175.0   2.92
# 1146   53       1       88            104           62    189.0   1.51
# 359    63       1       60            122           55    100.0  34.36
#
#       troponin
# 688      0.003
# 332      0.014
# 1178     0.028
# 443      0.007
# 1244     0.006
# ...        ...
# ...

# %%
X_res_test.columns
# Out:
# Index(['age', 'gender', 'impluse', 'pressurehight', 'pressurelow', 'glucose',
#        'kcm', 'troponin'],
#       dtype='object')

# %%
dec = DecisionTreeClassifier()
dec.fit(X_res_train,y_res_train)
# Out:
# DecisionTreeClassifier()

# %%
y_res_pred = dec.predict(X_res_test)

# %%
X_res = np.array([[64,1,66,160,83,160,1.8,0.012]])
X_res
# Out:
# array([[6.4e+01, 1.0e+00, 6.6e+01, 1.6e+02, 8.3e+01, 1.6e+02, 1.8e+00,
#         1.2e-02]])

# %%
y_res_pred = dec.predict(X_res)
y_res_pred
# Out:
# D:\Personal Projects\ML\Project_2\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['negative'], dtype=object)

# %%
import pickle

# %%
data = {"model": dec, 'age': df['age'], 'gender': df['gender'],'impluse':df['impluse'], 'pressurehight': df['pressurehight'], 'pressurelow': df['pressurelow'], 'glucose': df['glucose'],
       'kcm': df['kcm'], 'troponin': df['troponin']}
with open('saved_steps.pkl', 'wb') as file:
    pickle.dump(data, file)

# %%
with open('saved_steps.pkl', 'rb') as file:
    data = pickle.load(file)

model_loaded = data["model"]
age = data["age"]
gender= df['gender']
impluse = data["impluse"]
pressurehight = data["pressurehight"]
pressurelow = data["pressurelow"]
glucose = data["glucose"]
kcm = data["kcm"]
troponin = data['troponin']

# %%
y_pred = dec.predict(X_res)
y_pred
# Out:
# D:\Personal Projects\ML\Project_2\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['negative'], dtype=object)
